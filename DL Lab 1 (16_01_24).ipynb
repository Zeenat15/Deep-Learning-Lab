# %%
x_input = [0.1,0.5,0.2]
w_weight = [0.4,0.3,0.6]
threshold = 0.5

# %%
def step (weighted_sum):
  if weighted_sum >= threshold:
    return 1
  else:
    return 0

# %%
def perceptron():
  weighted_sum = 0
  for x,w in zip(x_input, w_weight):
    weighted_sum += x*w
    print(weighted_sum)
  return step(weighted_sum)

# %%
output = perceptron()
print("Output = ", output)
# Out:
# 0.04000000000000001
# 0.19
# 0.31
# Output =  0

# %% [markdown]
# # Change Threshold
# ## (Increase weight and decrease threshold)

# %%
x_input = [0.1,0.5,0.2]
w_weight = [0.4,0.3,0.8]
threshold = 0.2

# %%
def step (weighted_sum):
  if weighted_sum >= threshold:
    return 1
  else:
    return 0

# %%
def perceptron():
  weighted_sum = 0
  for x,w in zip(x_input, w_weight):
    weighted_sum += x*w
    print(weighted_sum)
  return step(weighted_sum)

# %%
output = perceptron()
print("Output = ", output)
# Out:
# 0.04000000000000001
# 0.19
# 0.35000000000000003
# Output =  1

# %% [markdown]
# # Perceptron of SKLEARN

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Age'].isna().sum()
# Out:
# 0

# %%
gender=pd.get_dummies(data['Sex'],drop_first=True)

# %%
data['Gender']=gender

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Gender           0
# dtype: int64

# %%
data['Age'] = data['Age'].astype(int)

# %%
x=data[['Pclass','Age','Gender']]
y=data['Survived']

# %%
#x=data.drop(['PassengerId','Survived','Name','Sex','SibSp','Parch','Ticket','Fare','Cabin','Embarked'],axis=1,inplace=True)
#y=data.drop(['PassengerId','Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked','Gender'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model = Perceptron()
model.fit(x_train,y_train)
y_predit = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_predit)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 59.33%

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train
# Out:
#      Pclass  Age  Gender
# 445       1    4       1
# 650       3   29       1
# 172       3    1       0
# 450       2   36       1
# 314       2   43       1
# ..      ...  ...     ...
# 106       3   21       0
# 270       1   29       1
# 860       3   41       1
# 435       1   14       0
# 102       1   21       1
#
# [623 rows x 3 columns]

# %%
y_train
# Out:
# 445    1
# 650    0
# 172    1
# 450    0
# 314    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: Survived, Length: 623, dtype: int64

# %%
x_test
# Out:
#      Pclass  Age  Gender
# 709       3   29       1
# 439       2   31       1
# 840       3   20       1
# 720       2    6       0
# 39        3   14       0
# ..      ...  ...     ...
# 821       3   27       1
# 633       1   29       1
# 456       1   65       1
# 500       3   17       1
# 430       1   28       1
#
# [268 rows x 3 columns]

# %%
y_test
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
#       ..
# 821    1
# 633    0
# 456    0
# 500    0
# 430    1
# Name: Survived, Length: 268, dtype: int64

# %%
import numpy as np

class Perceptron:
  def __init__(self, learning_rate, epochs):
    self.weights = None
    self.bias = None
    self.learning_rate = learning_rate
    self.epochs = epochs

  def activation(self, z):
    return np.heaviside(z,0)

  def fit(self, x, y):
    n_samples, n_features = x.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for epoch in range(self.epochs):
      for i in range(n_samples):
        z = np.dot(x.iloc[i], self.weights) + self.bias
        y_pred = self.activation(z)

        self.weights += self.learning_rate * (y - y_pred) * x.iloc[i]
        self.bias += self.learning_rate * (y - y_pred)

  def predict(self, x): # used for testing
    z = np.dot(x, self.weights) + self.bias
    return self.activation(z)

# %%
perceptron = Perceptron(0.01, 10)
perceptron.fit (x_train, y_train)
pred = perceptron.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-07a4831bc178> in <cell line: 2>()
#       1 perceptron = Perceptron(0.01, 10)
# ----> 2 perceptron.fit (x_train, y_train)
#       3 pred = perceptron.predict(x_test)
#
# <ipython-input-112-c721da77564a> in fit(self, x, y)
#      21         y_pred = self.activation(z)
#      22
# ---> 23         self.weights += self.learning_rate * (y - y_pred) * x.iloc[i]
#      24         self.bias += self.learning_rate * (y - y_pred)
#      25
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2111         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112     ):
# -> 2113         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2114
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predit)
